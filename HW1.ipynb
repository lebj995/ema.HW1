# %%
# hello world
if __name__ == '__main__':
    print("Hello, World!")

# %%
#python if-else
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n%2 != 0:
        print('Weird')
    else:
        if n%2==0 and 2<=n<=5:
            print('Not Weird')
        if n%2==0 and 6<=n<=20:
            print('Weird')
        if n%2==0 and n>20:
            print('Not Weird')

# %%
#arithmetic operaots
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
#python division
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
#loops
if __name__ == '__main__':
    n = int(input())
    i=0
    while i<n:
        print(i*i)
        i=i+1

# %%
#write a function
def is_leap(year):
    leap = False
    if year%4==0 and year%100!=0 or year%400==0:
        leap= True
    # Write your logic here
    
    return leap

# %%
#print function
if __name__ == '__main__':
    n = int(input())
    for i in range (1,n+1):
        print(i, end='')

# %%
#list comprehensions
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    l=[[i,j,k] for i  in range (x+1) for j in range(y+1) for k in range(z+1) if i+k+j!=n]
    print(l)

# %%
#find the runner-up score
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    l=list(arr)
    a = max(l)
    while a in l:
        l.remove(a)
    
    print(max(l))

# %%
#nested list
if __name__ == '__main__':
    a=[]
    for _ in range(int(input())):
        name = input()
        score = float(input())
        a.append([name,score])   
    voti= sorted(set(b[1]for b in a))
    secondo_voto= voti[1]
    secondo_studente= [b[0] for b in a if b[1]== secondo_voto]
    secondo_studente.sort()
    for i in secondo_studente:
        print(i)

# %%
#find the percentage
if __name__ == '__main__':
    n = int(input())
    voti = {}
    for i in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        voti[name] = scores
    query_name = input()
    avg= sum(voti[query_name])/len(voti[query_name])
    print(f'{avg:.2f}')

# %%
#tuples
import builtins 
if __name__ == '__main__':
    n = int(input())
    i = map(int, input().split())
    t= tuple(i)
    h=hash(t)
    print(h)

# %%
#swap case
def swap_case(s):
    new_string=''
    for i in s:
        if i.isupper():
            new_string+= i.lower()
        elif i.islower():
            new_string+=i.upper()
        else:
            new_string+=i    
    return new_string

# %%
#string split e join


def split_and_join(line):
    line=line.split(" ")
    line="-".join(line)
    return line

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#your name
#
# Complete the 'print_full_name' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    print(f"Hello {first} {last}! You just delved into python.")

# %%
#mutations
def mutate_string(string, position, character):
    l=list(string)
    l[position]= character
    string= ''.join(l)
    return string

# %%
#find a string
def count_substring(string, sub_string):
    occours=0
    for i in range(len(string)-len(sub_string)+1):
        if string[i:i+len(sub_string)]== sub_string:
            occours+=1
    return occours

# %%
#string validators
if __name__ == '__main__':
    s = input()
print(any(i.isalnum() for i in s))
print(any(i.isalpha() for i in s))
print(any(i.isdigit() for i in s))
print(any(i.islower() for i in s))
print(any(i.isupper() for i in s))

# %%
#text wrap
def wrap(string, max_width):
    a=textwrap.wrap(string, max_width)
    return '\n'.join(a)

# %%
#introduction to sets
def average(array):
    altezze = set(array)
    avg= sum(altezze)/len(altezze)
    return round(avg,3)

# %%
#symmetric difference
if __name__ == '__main__':
    M= int(input())
    b= set(map(int,input().split()))
    N= int(input())
    a= set(map(int, input().split()))
    union= a.union(b)
    intersection= a.intersection(b)
    symmetric_difference= union.difference(intersection)
    result= sorted(symmetric_difference)
    for i in result:
        print(i)

# %%
#set.add
n= int(input())
a= set()
for i in range(n):
    a.add(input())
number_of_country= len(a)
print(number_of_country)

# %%
#discad, remove, pop
n= int(input())
s= input().split()
s1= set(map(int,s))
N= int(input())


for i in range(N):
    a= input().split()
    if a[0]=='remove' and int(a[1]) in s1:
        s1.remove(int(a[1]))
    elif a[0]=='pop' and len(s1)>0:
        s1.pop()
    elif a[0]== 'discard':
        s1.discard(int(a[1]))
         
print(sum(s1))

# %%
#set union operation
a= int(input())
eng= set(map(int, input().split()))
b= int(input())
frc= set(map(int, input().split()))
unione= eng.union(frc)
totale= 0
for i in unione:
    totale+=1
print(totale)

# %%
#insertion
a = int(input())
english= set(map(int, input().split()))
b= int(input())
french = set(map(int,input().split()))
both_english_french= english.intersection(french)
print(len(both_english_french))

# %%
#difference
a= int(input())
english= set(map(int, input().split()))
b= int(input())
french= set(map(int, input().split()))
only_english= english.difference(french)
print(len(only_english))

# %%
#symmetric_difference
a= int(input())
english= set(map(int, input().split()))
b=int(input())
french= set(map(int, input().split()))
sym_diff= english.symmetric_difference(french)
print(len(sym_diff))

# %%
#set mutation
a = int(input())
A= set(map(int, input().split()))
N= int(input())
for i in range(N):
    operazioni= input().split()
    s= set(map(int, input().split()))
    if operazioni[0]=='intersection_update':
        A.intersection_update(s)
    elif operazioni[0]=='update':
        A.update(s)
    elif operazioni[0]=='difference_update':
        A.difference_update(s)
    elif operazioni[0]=='symmetric_difference_update':
        A.symmetric_difference_update(s)
       
print(sum(A))

# %%
#collection counnter
from collections import Counter
a = int(input())
size= Counter(map(int,input().split()))
N= int(input())
lista=[]
for i in range (N):
    lista.append(list(map(int,input().split())))
earn = 0
for j in lista:
    if j[0] in size.keys() and size[j[0]] :
        earn+= j[1]
        size[j[0]]-=1
print(earn)

# %%
#array

def arrays(arr):
    
    b= numpy.array(arr,float)
    return(b[::-1])

# %%
#shape, reshape
import numpy
a = input().split()
a= numpy.array(a,dtype=int)
b=numpy.reshape(a,(3,3))
print(b)

# %%
]#transopose, flatten
import numpy
n,m= map(int,input().split())
my_list=[]
for i in range(n):
    riga= list(map(int,input().split()))
    my_list.append(riga)
my_array= numpy.array(my_list)
print(numpy.transpose(my_array))
print(my_array.flatten())

# %%
#concatenate
import numpy
n,m,p = map(int,input().split()) 
arr1=[]
arr2=[]
for i in range(n):
    riga1=(list(map(int,input().split())))
    arr1.append(riga1)
for j in range(m):
    riga2=(list(map(int,input().split())))
    arr2.append(riga2)
array_1= numpy.array(arr1,int)
array_2= numpy.array(arr2,int)
print (numpy.concatenate((array_1,array_2), axis=0))

# %%
#zeros e ones
import numpy
n= list(map(int,input().split()))

a=(numpy.zeros((n), dtype = int))
b=(numpy.ones((n), dtype = int))
print(a)
print(b)

# %%
#eye, identity
import numpy
numpy.set_printoptions(legacy='1.13')
n,m= map(int,input().split())
print(numpy.eye(n,m,k=0))

# %%
#array_mathematics
import numpy
n,m = map(int,input().split())
a= numpy.array([list(map(int,input().split())) for i in range(n)],int)
b= numpy.array([list(map(int,input().split())) for i in range(n)],int)

print(a+b)
print(a-b)
print(a*b)
print(numpy.floor_divide(a,b))
print(a%b)
print(a**b)

# %%
#floor, ceil, rint
import numpy
numpy.set_printoptions(legacy='1.13')
a= list(map(float,input().split()))
my_array= numpy.array(a)
print(numpy.floor(my_array))
print(numpy.ceil(my_array))
print(numpy.rint(my_array))

# %%
#sum e prod
import numpy
n,m = list(map(int,input().split()))
lista=[]
for i in range(n):
    

    lista.append(list(map(int,input().split())))
my_array= numpy.array(lista)
my_array_2= numpy.sum(my_array, axis=0)
a= numpy.prod(my_array_2)
print(a)

# %%
#min e max
import numpy
n,m= list(map(int,input().split()))
lista=[]
for i in range(n):
    lista.append(list(map(int,input().split())))
my_array=numpy.array(lista)
my_array= numpy.min(my_array,axis=1)
print(numpy.max(my_array))

# %%
#dot e cross
import numpy
n= int(input())
matrice_1= []
matrice_2=[]
for i in range(n):
    matrice_1.append(list(map(int,input().split())))
for i in range(n):
    matrice_2.append(list(map(int,input().split())))
array_1= numpy.array(matrice_1)

array_2= numpy.array(matrice_2)
print(numpy.dot(array_1,array_2))

# %%
#inner outer
import numpy as np
a=list(map(int,input().split()))
b=list(map(int,input().split()))
arr1= np.array(a)
arr2=np.array(b)
print(np.inner(a,b))
print(np.outer(a,b))

# %%
#polynomial
import numpy
p= list(map(float,input().split()))
x=int(input())
p2= numpy.array(p)
print(numpy.polyval(p2,x))

# %%
#linear algebra
import numpy
n= int(input())
lista=[]

for i in range(n):
    lista.append(list(map(float,input().split())))
array_1=numpy.array(lista)
print(round(numpy.linalg.det(array_1),2))

# %%
#no idea
n,m= list(map(int,input().split()))
array=list(map(int,input().split()))
a= set(map(int,input().split()))
b= set(map(int,input().split()))
happiness=0
for i in array:
    if i in a:
        happiness+=1
    if i in b:
        happiness-=1 
print(happiness)

# %%
#check subset
t= int(input())

for i in range(t):
    number_a=int(input())
    a= set(map(int,input().split()))
    number_b=int(input())
    b= set(map(int,input().split()))
    if a.issubset(b):
        print('True')
    else:
        print('False')

# %%
#stric superset
a= set(map(int,input().split()))
n=int(input())

l=[]
for i in range(n):
    n2=set(map(int,input().split()))
    
    
    if (n2.issubset(a) and len(a)>len(n2)):
        l.append(True)
    else:
        l.append(False)
    
print(all(l))

# %%
#text alignment
#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))

# %%
#string formmattig
def print_formatted(number):
    l= len(bin(number))-2
    for i in range(1,number+1):
        decimal= str(i).rjust(l)
        octal= oct(i)[2:].rjust(l)
        hexa= hex(i)[2:].upper().rjust(l)
        binary= bin(i)[2:].rjust(l)
        print(decimal, octal, hexa, binary)

# %%
#merge the tools!!!!!!!!!
def merge_the_tools(string, k):
    
    for j in range(0,len(string),k):
        a=''
        stringa_2= string[j:j+k]
        for i in stringa_2:
            if i not in a:
                a+=i
        print(a)

# %%
#the capitain totti room
from collections import Counter
k=int(input())
room_number= list(map(int,input().split()))

a= Counter(room_number)
for room_number,i in a.items():
    if i==1:
        print(room_number)
        break

# %%
#namedtuple
from collections import namedtuple
n= int(input())
a= input()
studenti= namedtuple('studenti',a)
voti=0
for i in range(n):
    b= studenti(*input().split())
    voti+= int(b.MARKS)
    
media= voti/n
print(float(media))

# %%
#orderedict
from collections import OrderedDict
n=int(input())
dizionario= OrderedDict()
for i  in range(n):
    item_price= input().split()
    item= ' '.join(item_price[:-1])
    price= int(item_price[-1])
    if item not in dizionario.keys():
        dizionario[item]= price
    else:
        dizionario[item]+=price
for item,price in dizionario.items():
    print(item,price)

# %%
#deque
from collections import deque
n= int(input())
d= deque()
for i in range(n):
    metodi= input().split()
    operazioni = metodi[0]
    if len(metodi)>1:
        valori= int(metodi[1])
    if operazioni=='append':
        d.append(valori)
    elif operazioni=='appendleft':
        d.appendleft(valori)
    elif operazioni=='clear':
        d.clear()
    elif operazioni=='extend':
        d.extend(valori)
    elif operazioni=='extendleft':
        d.extendleft(valori)
    elif operazioni=='pop':
        d.pop()
    elif operazioni=='popleft':
        d.popleft()
    elif operazioni=='rotate':
        d.rotate(valori)
    elif operazioni=='reverse':
        d.reverse()
    elif operazioni=='remove':
        d.remove(valori)
    elif operazioni=='count':
        d.count(valori)
print(*d)

# %%
#word order
from collections import Counter
n=int(input())
l=[]
for i in range(n):
    word= input().split()
    l.extend(word)
occorrenze= Counter(l)
print(len(occorrenze.keys()))
for i in occorrenze:
    print(occorrenze[i], end=' ')

# %%
#defaultdict
from collections import defaultdict
n,m =map(int,input().split())
A= defaultdict(list)
for i in range(n):
    a=input().strip()
    A[a].append(i+1)
for i in range(m):
    b=input().strip()
    if b in A:
        print(*A[b])
    else:
        print(-1)

# %%
#pilling up
T=int(input())
for i in range(T):
    results=True
    n=int(input())
    
    blocks=list(map(int, input().split()))
    top= 30**100
    
    
    while blocks:
        if blocks[0]<=top and blocks[0]>=blocks[-1]:
            top= blocks.pop(0)
            
        elif blocks[-1]<=top and blocks[0]<=blocks[-1]:
            top= blocks.pop()
        else:
            results=False
            break
        
    if results==True:
        print('Yes')
    else:
        print('No')

# %%
#calendar module
import calendar
data= list(map(int,input().split()))
y= data[2]
m= data[0]
d= data[1]
day= calendar.weekday(y,m,d)
if day==0:
    print('MONDAY')
if day==1:
    print('TUESDAY')
if day==2:
    print('WEDNESDAY')
if day==3:
    print('THURSDAY')
if day==4:
    print('FRIDAY')
if day==5:
    print('SATURDAY')
if day==6:
    print('SUNDAY')

# %%
#execption
T= int(input())
for i in range(T):
    try:
        a,b= input().split()
        print(int(a)//int(b))
    except ZeroDivisionError as e:
        print('Error Code:',e)
    except ValueError as e:
        print('Error Code:',e)

# %%
#birthday cake
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    a=max(candles)
    return(candles.count(a))
    # Write your code here

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#number line jumps
#!/bin/python3

import math
import os
import random
import re
import sys

def kangaroo(x1, v1, x2, v2):
    
    if (x1<x2 and v1<v2 or x1>x2 and v1>v2) or (x1<x2 and v1==v2 or x1>x2 and v1==v2):
        return 'NO'
    
    elif (x2-x1)%(v1-v2)==0:
        return 'YES'
    else:
        return'NO'

            
                    
    



                    
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result+'\n')

    fptr.close()

# %%
#viral advertising
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    a=0
    s=5
    totale=0
    for i in range(n):
        a =s//2
        totale+= a
        s=a*3
    return totale
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#recooursive digit sum
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k
#

def superDigit(n, k):
    concatenate= str(sum(int(i)for i in str(n)))*k
    totale=0
    a=0
    for i in concatenate:
        totale+=int(i)
    while len(str(totale))>1:
        a=0
        for i in str(totale):
            a += int(i)
        totale= a
    return a
        
    # Write your code here

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#array mathematics
import numpy
n,m = map(int,input().split())
a= numpy.array([list(map(int,input().split())) for i in range(n)],int)
b= numpy.array([list(map(int,input().split())) for i in range(n)],int)

print(a+b)
print(a-b)
print(a*b)
print(numpy.floor_divide(a,b))
print(a%b)
print(a**b)

# %%
#detect floting point number
import re
t=int(input())
for i in range(t):
    n=input().strip()
    numero= re.compile(r'^[+-]?[0-9]*\.[0-9]+$')
    if re.fullmatch(numero,n):
        print(True)
    else:
        print(False)

# %%
#insertion part 1
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    s= arr[-1]
    for i in range(len(arr)-2, -1, -1):
        if arr[i]>s:
            arr[i+1]=arr[i]
            print(*arr)
        else:
            arr[i+1]=s
            print(*arr)
            break
    else:
        arr[0]=s
        print(*arr)
            
    

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
#zipperd
n,x = map(int,input().split())
voti=[]
for i in range(x):
    mark=list(map(float,input().split()))
    voti.append(mark)
    
for i in zip(*voti):
    print(sum(i)/x)

# %%
#ginort
s= input().strip()
maiuscole=[]
minuscole=[]
dispari=[]
pari=[]
for i in s:
    if i.isupper():
        maiuscole.append(i)
    elif i.islower():
        minuscole.append(i)
    elif i.isnumeric():
        if int(i)%2 ==0:
            pari.append(i)
        else:
            dispari.append(i)
maiuscole= sorted(maiuscole)
minuscole=sorted(minuscole)
pari= sorted(pari)
dispari= sorted(dispari)
print(''.join(minuscole+maiuscole+dispari+pari))

# %%
#re.split
regex_pattern = r"\.|\,"	# Do not delete 'r'.

# %%
#groups
import re
s= input().strip()
controllo= re.search(r'([a-zA-Z0-9])\1+', s)
if controllo:
    print(controllo.group(1))
        
else:
    print(-1)

# %%
#insertuon part 2
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    for i in range(1,n):
        b=arr[i]
        a=i-1
        
        while arr[a]> b and a>=0:
            arr[a+1]= arr[a]
            a=a-1
        arr[a+1]=b
        print(*arr)
        

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)

# %%
#mean,var,std
import numpy


n,m= list(map(int,input().split()))
lista=[]
for i in range(n):
    lista.append(list(map(int,input().split())))
my_array=numpy.array(lista)
print(numpy.mean(my_array,axis=1))
print(numpy.var(my_array,axis=0))
print(round(numpy.std(my_array, axis= None),11))
